# %%
from tkinter import *
from PIL import Image,ImageTk
import tkinter.messagebox

def validate():
    name= entry_1.get()
    email= entry_2.get()
    country= c.get()
    programming= var2.get()
    gender= var.get()
    if (name=="" or email=="" or country== 'Select your country'or programming == 0 or gender == 0):
        tkinter.messagebox.showinfo('Invalid Message Alert',"Fields cannot be left empty!")

    else:
        tkinter.messagebox.showinfo('Success Message',"Successfully registered!")
        

   
root = Tk()
root.geometry('600x600')
root.title("HOSTEL REGISTRATION FORM")

bg = ImageTk.PhotoImage(file = "background.jpeg")
label = Label( root, image = bg)
label.place(x = 0, y = 0)


label_0 = Label(root, text="HOSTEL REGISTRATION FORM",width=30,font=("bold", 20))
label_0.place(x=90,y=53)

label_1 = Label(root, text="Hostel Name: ",width=20,font=("bold", 10))
label_1.place(x=80,y=130)

entry_1 = Entry(root)
entry_1.place(x=240,y=130)

label_2 = Label(root, text="Hostel Number: ",width=20,font=("bold", 10))
label_2.place(x=68,y=180)

entry_2 = Entry(root)
entry_2.place(x=240,y=180)

label_3 = Label(root, text="Full Name: ",width=20,font=("bold", 10))
label_3.place(x=68,y=230)

entry_3 = Entry(root)
entry_3.place(x=240,y=230)

label_4 = Label(root, text="Roll Number: ",width=20,font=("bold", 10))
label_4.place(x=68,y=280)

entry_4 = Entry(root)
entry_4.place(x=240,y=280)

label_5 = Label(root, text="Contact Number: ",width=20,font=("bold", 10))
label_5.place(x=68,y=330)

entry_6 = Entry(root)
entry_6.place(x=240,y=330)

label_7 = Label(root, text="Email-ID: ",width=20,font=("bold", 10))
label_7.place(x=68,y=380)

entry_7 = Entry(root)
entry_7.place(x=240,y=380)

label_8 = Label(root, text="Father's Name: ",width=20,font=("bold", 10))
label_8.place(x=68,y=430)

entry_8 = Entry(root)
entry_8.place(x=240,y=430)

label_9 = Label(root, text="Mother's Name: ",width=20,font=("bold", 10))
label_9.place(x=68,y=480)

entry_9 = Entry(root)
entry_9.place(x=240,y=480)

label_10 = Label(root, text="Address: ",width=20,font=("bold", 10))
label_10.place(x=68,y=530)

entry_10 = Entry(root)
entry_10.place(x=240,y=530)

chk = Checkbutton(root, text = "I hereby declare the information provided by me is legitimate.",onvalue=1,offvalue=0).place(x=70,y=570)

btn = Button(root, text="Submit").place(x=230,y=600)

# label_3 = Label(root, text="Gender",width=20,font=("bold", 10))
# label_3.place(x=70,y=230)
# var = IntVar()
# Radiobutton(root, text="Male",padx = 5, variable=var, value=1).place(x=235,y=230)
# Radiobutton(root, text="Female",padx = 20, variable=var, value=2).place(x=290,y=230)

# label_4 = Label(root, text="Country",width=20,font=("bold", 10))
# label_4.place(x=70,y=280)

# list1 = ['Canada','India','UK','Nepal','Iceland','South Africa'];
# c=StringVar()
# droplist=OptionMenu(root,c, *list1)
# droplist.config(width=15)
# c.set('Select your country') 
# droplist.place(x=240,y=280)

# label_4 = Label(root, text="Programming",width=20,font=("bold", 10))
# label_4.place(x=85,y=330)
# var1 = IntVar()
# Checkbutton(root, text="C++", variable=var1).place(x=235,y=330)
# var2 = IntVar()
# Checkbutton(root, text="Python", variable=var2).place(x=290,y=330)

# Button(root, text='Submit',width=20,bg='green',fg='white', command = validate).place(x=180,y=380)
# chk.pack()

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-869c04863093> in <module>
#      21 root.title("HOSTEL REGISTRATION FORM")
#      22
# ---> 23 bg = ImageTk.PhotoImage(file = "background.jpeg")
#      24 label = Label( root, image = bg)
#      25 label.place(x = 0, y = 0)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/PIL/ImageTk.py in __init__(self, image, size, **kw)
#      87         # Tk compatibility: file or data
#      88         if image is None:
# ---> 89             image = _get_image_from_kw(kw)
#      90
#      91         if hasattr(image, "mode") and hasattr(image, "size"):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/PIL/ImageTk.py in _get_image_from_kw(kw)
#      56         source = BytesIO(kw.pop("data"))
#      57     if source:
# ---> 58         return Image.open(source)
#      59
#      60
#
# ...
