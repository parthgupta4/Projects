# %%
from tkinter import *
import mysql.connector
import tkinter.messagebox

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="parth123",
    database="hostel1"
     
)

global roll_number


mycursor = mydb.cursor()

def display():
        display_query = Tk()
        display_query.title("Display")
        display_query.geometry('800x600')
        
        def close_admin_page():
            display_query.destroy()

        mycursor.execute("SELECT* FROM students")
        result = mycursor.fetchall()
        
        def update():
            sql_command="""UPDATE students SET h_name=%s, h_num=%s, name=%s, room_num=%s, contact=%s, email=%s, f_name=%s, m_name=%s, address=%s WHERE roll_num=%s """
            h_name = entry_12.get()
            h_num = entry_22.get()
            name = entry_32.get()
            room_num = entry_52.get()
            contact = entry_62.get()
            email = entry_72.get()
            f_name = entry_82.get()
            m_name = entry_92.get()
            address = entry_102.get()
            
            roll_num = entry_42.get()
            
            inputs=(h_name, h_num, name, room_num, contact, email, f_name, m_name, address, roll_num)
            mycursor.execute(sql_command, inputs)
            mydb.commit()
            
            display_query.destroy()
            
            
        def save():
            roll =entry_42.get()
            sql3 = "DELETE FROM students WHERE roll_num=%s"
            
            name3= (roll, )
            mycursor.execute(sql3,name3)
            mydb.commit()
            
            
            delete_label = Label(display_query, text="The record is succesfully deleted!").place(x=240,y=500)

                
        
        def edit_val(id,index):
            
            sql2 = "SELECT * FROM students WHERE roll_num=%s"
            name2 = (id, )
            result2 = mycursor.execute(sql2,name2)
            result2 = mycursor.fetchall()
            
            global entry_12
            label_12 = Label(display_query, text="Hostel Name: ",width=20,font=("bold", 10))
            label_12.place(x=80,y=130)

            entry_12 = Entry(display_query)
            entry_12.place(x=240,y=130)

            global entry_22
            label_22 = Label(display_query, text="Hostel Number: ",width=20,font=("bold", 10))
            label_22.place(x=68,y=160)

            entry_22 = Entry(display_query)
            entry_22.place(x=240,y=160)

            global entry_32
            label_32 = Label(display_query, text="Full Name: ",width=20,font=("bold", 10))
            label_32.place(x=68,y=190)

            entry_32 = Entry(display_query)
            entry_32.place(x=240,y=190)

            global entry_42
            label_42 = Label(display_query, text="Roll Number: ",width=20,font=("bold", 10))
            label_42.place(x=68,y=220)

            entry_42 = Entry(display_query)
            entry_42.place(x=240,y=220)

            global entry_52
            label_52 = Label(display_query, text="Room Number: ",width=20,font=("bold", 10))
            label_52.place(x=68,y=250)

            entry_52 = Entry(display_query)
            entry_52.place(x=240,y=250)

            global entry_62
            label_62 = Label(display_query, text="Contact Number: ",width=20,font=("bold", 10))
            label_62.place(x=68,y=280)

            entry_62 = Entry(display_query)
            entry_62.place(x=240,y=280)

            global entry_72
            label_72 = Label(display_query, text="Email-ID: ",width=20,font=("bold", 10))
            label_72.place(x=68,y=310)

            entry_72 = Entry(display_query)
            entry_72.place(x=240,y=310)

            global entry_82
            label_82 = Label(display_query, text="Father's Name: ",width=20,font=("bold", 10))
            label_82.place(x=68,y=340)

            entry_82 = Entry(display_query)
            entry_82.place(x=240,y=340)

            global entry_92
            label_92 = Label(display_query, text="Mother's Name: ",width=20,font=("bold", 10))
            label_92.place(x=68,y=370)

            entry_92 = Entry(display_query)
            entry_92.place(x=240,y=370)

            global entry_102
            label_102 = Label(display_query, text="Address: ",width=20,font=("bold", 10))
            label_102.place(x=68,y=400)

            entry_102 = Entry(display_query)
            entry_102.place(x=240,y=400)
            
            save_record = Button(display_query, text="UPDATE", command=update).place(x=240,y=500)

            

        for index,x in enumerate(result):
            num=0
            index+=2
            reference_id = str(x[4])
            edit_button = Button(display_query, text="Edit", command=lambda: edit_val(reference_id,index))
            edit_button.grid(row=index,column=num+1)

            for y in x:
                display_label = Label(display_query, text=y)
                display_label.grid(row=index,column=num+2)
                num+=1
                
            close_btn = Button(display_query, text="CLOSE", command=close_admin_page).place(x=350,y=350)
                
def laundry_reg():
    
    laundry_tab = Tk()
    laundry_tab.geometry('500x500')
    laundry_tab.title("LAUNDRY FORM")
    def clear():
        entry_1.delete(0,END)
        entry_2.delete(0,END)
        menu.delete(0,END)
        entry_4.delete(0,END)
        entry_5.delete(0,END)
        
    def laundry_add_record():
        sql_command = "INSERT INTO laundry (l_id, roll_num, l_status, l_fee, l_fine) VALUES (%s, %s, %s, %s, %s)"
        values=(entry_1.get(), entry_2.get(), menu.get(), entry_4.get(), entry_5.get())
        mycursor.execute(sql_command,values)
        mydb.commit()
        clear()
        
    def close_laundry_tab():
        laundry_tab.destroy()
                
    label_0 = Label(laundry_tab, text="LAUNDRY REGISTRATION FORM",width=25,font=("bold", 20))
    label_0.place(x=90,y=53)

    label_1 = Label(laundry_tab, text="Laundry ID: ",width=20,font=("bold", 10))
    label_1.place(x=80,y=130)

    global entry_1
    entry_1 = Entry(laundry_tab)
    entry_1.place(x=240,y=130)

    label_2 = Label(laundry_tab, text="Roll Number: ",width=20,font=("bold", 10))
    label_2.place(x=68,y=160)

    global entry_2
    entry_2 = Entry(laundry_tab)
    entry_2.place(x=240,y=160)
    roll_number = entry_2.get()
    
    menu = StringVar()
    menu.set("Select TRUE/FALSE")
    
    label_3 = Label(laundry_tab, text="Status [true/false]: ",width=20,font=("bold", 10))
    label_3.place(x=68,y=190)

    global entry_3
    
    menu = StringVar()
    menu.set("Select TRUE/FALSE")
    entry_3 = OptionMenu(laundry_tab, menu, "true","false")
    entry_3.pack()
    entry_3.place(x=240,y=190)

    label_4 = Label(laundry_tab, text="Laundry Fee: ",width=20,font=("bold", 10))
    label_4.place(x=68,y=220)

    global entry_4
    entry_4 = Entry(laundry_tab)
    entry_4.place(x=240,y=220)

    label_5 = Label(laundry_tab, text="Laundry Fine: ",width=20,font=("bold", 10))
    label_5.place(x=68,y=250)

    global entry_5
    entry_5 = Entry(laundry_tab)
    entry_5.place(x=240,y=250) 
    
    submit_btn = Button(laundry_tab, text="SUBMIT", command = laundry_add_record)
    submit_btn.place(x=160,y=320)
    
    close_btn = Button(laundry_tab, text="CLOSE", command=close_laundry_tab)
    close_btn.place(x=280,y=320)


                

def mess_reg():
    
    mess_tab = Tk()
    mess_tab.geometry('500x500')
    mess_tab.title("MESS FORM")
    def clear():
        entry_1.delete(0,END)
        entry_2.delete(0,END)
        menu.delete(0,END)
        entry_4.delete(0,END)
        entry_5.delete(0,END)
        
    def mess_add_record():
        sql_command = "INSERT INTO mess (mess_id, roll_num, mess_status, mess_fee, mess_fine) VALUES (%s, %s, %s, %s, %s)"
        values=(entry_1.get(), entry_2.get(), menu.get(), entry_4.get(), entry_5.get())
        mycursor.execute(sql_command,values)
        mydb.commit()
        clear()
        
    def close_mess_tab():
        mess_tab.destroy()
                
    label_0 = Label(mess_tab, text="MESS REGISTRATION FORM",width=25,font=("bold", 20))
    label_0.place(x=90,y=53)

    label_1 = Label(mess_tab, text="Mess ID: ",width=20,font=("bold", 10))
    label_1.place(x=80,y=130)

    global entry_1
    entry_1 = Entry(mess_tab)
    entry_1.place(x=240,y=130)

    label_2 = Label(mess_tab, text="Roll Number: ",width=20,font=("bold", 10))
    label_2.place(x=68,y=160)

    global entry_2
    entry_2 = Entry(mess_tab)
    entry_2.place(x=240,y=160)
    roll_number = entry_2.get()

    label_3 = Label(mess_tab, text="Status [true/false]: ",width=20,font=("bold", 10))
    label_3.place(x=68,y=190)
    
    menu = StringVar()
    menu.set("Select TRUE/FALSE")

    label_3 = Label(mess_tab, text="Status [true/false]: ",width=20,font=("bold", 10))
    label_3.place(x=68,y=190)

    global entry_3
    
    menu = StringVar()
    menu.set("Select TRUE/FALSE")
    entry_3 = OptionMenu(mess_tab, menu, "true","false")
    entry_3.pack()
    entry_3.place(x=240,y=190)

    label_4 = Label(mess_tab, text="Mess Fee: ",width=20,font=("bold", 10))
    label_4.place(x=68,y=220)

    global entry_4
    entry_4 = Entry(mess_tab)
    entry_4.place(x=240,y=220)

    label_5 = Label(mess_tab, text="Mess Fine: ",width=20,font=("bold", 10))
    label_5.place(x=68,y=250)

    global entry_5
    entry_5 = Entry(mess_tab)
    entry_5.place(x=240,y=250) 
    
    submit_btn = Button(mess_tab, text="SUBMIT", command=mess_add_record)
    submit_btn.place(x=160,y=320)
    
    close_btn = Button(mess_tab, text="CLOSE", command=close_mess_tab)
    close_btn.place(x=280,y=320)


global user_details


def search_user():
    
    user_data = Tk()
    user_data.title("USER DETAILS")
    user_data.geometry('300x200')
    
    login_label = Label(user_data, text="USER LOGIN",font=("bold", 16))
    login_label.place(x=100,y=10)
    
    data_box_label = Label(user_data, text="Roll Number: ").place(x=10,y=40)
    data_box = Entry(user_data)
    data_box.place(x=100,y=40)
    
    passwd_box_label = Label(user_data, text="Password: ").place(x=10,y=70)
    passwd_box = Entry(user_data,show="*")
    passwd_box.place(x=100,y=70)
        
    def search():
                se = data_box.get()
                sql = "SELECT * FROM students WHERE roll_num = %s"
                name=(se, )
                result = mycursor.execute(sql,name)
                result = mycursor.fetchall()

                user_details = Tk()
                user_details.geometry('600x600')
                user_details.title("USER DETAILS")

                def close_user_details():
                    user_details.destroy()

                if not result:
                    result = "Record Not Found...."

                print_rec=''
                index=0

                l1 = Label(user_details,text="Hostel Name: ").place(x=10,y=0)
                l2 = Label(user_details,text="Hostel Number: ").place(x=10,y=25)
                l3 = Label(user_details,text="Student Name: ").place(x=10,y=50)
                l4 = Label(user_details,text="Roll Number: ").place(x=10,y=75)
                l5 = Label(user_details,text="Room Number: ").place(x=10,y=100)
                l6 = Label(user_details,text="Contact Number: ").place(x=10,y=125)
                l7 = Label(user_details,text="Email ID: ").place(x=10,y=150)
                l8 = Label(user_details,text="Father's Name: ").place(x=10,y=175)
                l9 = Label(user_details,text="Mother's Name: ").place(x=10,y=200)
                l10 = Label(user_details,text="Address: ").place(x=10,y=225)

                for x in result[0]:
                    print_rec = str(x)+"\n"
                    l = Label(user_details,text=print_rec)
                    l.place(x=180,y=index)
                    index+=25



                def mess_display():
                    display_mess = Tk()
                    display_mess.title("Display")
                    display_mess.geometry('1000x600')


                    def close_mess_details():
                        display_mess.destroy()

                    sql="""SELECT* FROM students NATURAL JOIN mess WHERE roll_num=%s """
                    name=(se, )
                    mycursor.execute(sql,name)
                    result = mycursor.fetchall()

                    l1=Label(display_mess,text="Roll No.", font=('bold 12 underline')).grid(row=0,column=0)
                    l2=Label(display_mess,text="Hostel Name", font=('bold 12 underline')).grid(row=0,column=1)
                    l3=Label(display_mess,text="Hostel No.", font=('bold 12 underline')).grid(row=0,column=2)
                    l4=Label(display_mess,text="Name", font=('bold 12 underline')).grid(row=0,column=3)
                    l5=Label(display_mess,text="Room No.", font=('bold 12 underline')).grid(row=0,column=4)
                    l6=Label(display_mess,text="Contact", font=('bold 12 underline')).grid(row=0,column=5)
                    l7=Label(display_mess,text="Email-ID", font=('bold 12 underline')).grid(row=0,column=6)
                    l8=Label(display_mess,text="Father's Name", font=('bold 12 underline')).grid(row=0,column=7)
                    l9=Label(display_mess,text="Mother's Name", font=('bold 12 underline')).grid(row=0,column=8)
                    l10=Label(display_mess,text="Address", font=('bold 12 underline')).grid(row=0,column=9)
                    l11=Label(display_mess,text="Mess ID", font=('bold 12 underline')).grid(row=0,column=10)
                    l12=Label(display_mess,text="Mess Status", font=('bold 12 underline')).grid(row=0,column=11)
                    l13=Label(display_mess,text="Mess Fee", font=('bold 12 underline')).grid(row=0,column=12)
                    l14=Label(display_mess,text="mess Fine", font=('bold 12 underline')).grid(row=0,column=13)

                    for index,x in enumerate(result):
                        num=0
                        for y in x:
                            display_label = Label(display_mess, text=y)
                            display_label.grid(row=index+1,column=num)
                            num+=1

                    l15 = Button(display_mess, text="CLOSE", command=close_mess_details).place(x=450,y=300)

                def laundry_display():
                    display_laundry = Tk()
                    display_laundry.title("Display")
                    display_laundry.geometry('1200x600')

                    def close_laundry_details():
                        display_laundry.destroy()


                    sql="""SELECT* FROM students NATURAL JOIN laundry WHERE roll_num=%s AND l_status='true' """
                    name=(se, )
                    mycursor.execute(sql,name)
                    result2 = mycursor.fetchall()

                    l1=Label(display_laundry,text="Roll No.", font=('bold 12 underline')).grid(row=0,column=0)
                    l2=Label(display_laundry,text="Hostel Name", font=('bold 12 underline')).grid(row=0,column=1)
                    l3=Label(display_laundry,text="Hostel No.", font=('bold 12 underline')).grid(row=0,column=2)
                    l4=Label(display_laundry,text="Name", font=('bold 12 underline')).grid(row=0,column=3)
                    l5=Label(display_laundry,text="Room No.", font=('bold 12 underline')).grid(row=0,column=4)
                    l6=Label(display_laundry,text="Contact", font=('bold 12 underline')).grid(row=0,column=5)
                    l7=Label(display_laundry,text="Email-ID", font=('bold 12 underline')).grid(row=0,column=6)
                    l8=Label(display_laundry,text="Father's Name", font=('bold 12 underline')).grid(row=0,column=7)
                    l9=Label(display_laundry,text="Mother's Name", font=('bold 12 underline')).grid(row=0,column=8)
                    l10=Label(display_laundry,text="Address", font=('bold 12 underline')).grid(row=0,column=9)
                    l11=Label(display_laundry,text="Laundry ID", font=('bold 12 underline')).grid(row=0,column=10)
                    l12=Label(display_laundry,text="Laundry Status", font=('bold 12 underline')).grid(row=0,column=11)
                    l13=Label(display_laundry,text="Laundry Fee", font=('bold 12 underline')).grid(row=0,column=12)
                    l14=Label(display_laundry,text="Laundry Fine", font=('bold 12 underline')).grid(row=0,column=13)



                    for index,x in enumerate(result2):
                        num=0
                        for y in x:
                            display_label = Label(display_laundry, text=y)
                            display_label.grid(row=index+1,column=num)
                            num+=1

                    l15 = Button(display_laundry, text="CLOSE", command=close_laundry_details).place(x=550,y=300)

                mess_button= Button(user_details,text="AVAIL MESS", command=mess_reg)
                mess_button.place(x=100,y=300)

                display_mess_btn = Button(user_details, text="MESS DETAILS", command=mess_display)
                display_mess_btn.place(x=100,y=330)

                laundry_button= Button(user_details,text="AVAIL LAUNDRY", command=laundry_reg)
                laundry_button.place(x=300,y=300)

                display_laundry_btn = Button(user_details, text="LAUNDRY DETAILS", command=laundry_display)
                display_laundry_btn.place(x=300,y=330)

                close_btn = Button(user_details, text="CLOSE", command=close_user_details).place(x=230,y=360)
                
    if (passwd_box.get()!=data_box.get()):
        messagebox.showerror("Error","Incorrect Password",parent=user_data)

    
    search_btn = Button(user_data, text="ENTER", command=search).place(x=95,y=100) 
    
def delete():
    
    del_query = Tk()
    del_query.geometry("400x200")
    del_query.title("DELETE RECORD")
    
    def delete_record():
        roll = del_box.get()
        sql3 = "DELETE FROM students WHERE roll_num=%s"
        name=(roll, )
        mycursor.execute(sql3, name)
        mydb.commit()
        
        del_query.destroy()   
    
    del_label = Label(del_query, text="Enter the Roll Number: ").place(x=30,y=50)
    del_box = Entry(del_query)
    del_box.place(x=180,y=50)
    
    del_btn = Button(del_query, text="DELETE RECORD", command=delete_record).place(x=150,y=100)
            

def registration():
    def clear():
        entry_1.delete(0,END)
        entry_2.delete(0,END)
        entry_3.delete(0,END)
        entry_4.delete(0,END)
        entry_5.delete(0,END)
        entry_6.delete(0,END)
        entry_7.delete(0,END)
        entry_8.delete(0,END)
        entry_9.delete(0,END)
        entry_10.delete(0,END)

    def add_record():
        sql_command = "INSERT INTO students (h_name, h_num, name, roll_num, room_num, contact, email, f_name, m_name, address) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
        values=(entry_1.get(), entry_2.get(), entry_3.get(), entry_4.get(), entry_5.get(), entry_6.get(), entry_7.get(), entry_8.get(), entry_9.get(), entry_10.get())
        mycursor.execute(sql_command,values)
        mydb.commit()
        clear()
        
        messagebox.showinfo("SUCCESS","REGISTERED SUCCESFULLY.", parent=root)

    root = Tk()
    root.geometry('600x600')
    root.title("HOSTEL REGISTRATION FORM")
    
    def close_form():
        root.destroy()

    label_0 = Label(root, text="HOSTEL REGISTRATION FORM",width=25,font=("bold", 20))
    label_0.place(x=95,y=53)

    label_1 = Label(root, text="Hostel Name: ",width=20,font=("bold", 10))
    label_1.place(x=95,y=130)

    entry_1 = Entry(root)
    entry_1.place(x=255,y=130)

    label_2 = Label(root, text="Hostel Number: ",width=20,font=("bold", 10))
    label_2.place(x=83,y=160)

    entry_2 = Entry(root)
    entry_2.place(x=255,y=160)

    label_3 = Label(root, text="Full Name: ",width=20,font=("bold", 10))
    label_3.place(x=83,y=190)

    entry_3 = Entry(root)
    entry_3.place(x=255,y=190)

    label_4 = Label(root, text="Roll Number: ",width=20,font=("bold", 10))
    label_4.place(x=83,y=220)

    entry_4 = Entry(root)
    entry_4.place(x=255,y=220)

    label_5 = Label(root, text="Room Number: ",width=20,font=("bold", 10))
    label_5.place(x=83,y=250)

    entry_5 = Entry(root)
    entry_5.place(x=255,y=250)


    label_6 = Label(root, text="Contact Number: ",width=20,font=("bold", 10))
    label_6.place(x=83,y=280)

    entry_6 = Entry(root)
    entry_6.place(x=255,y=280)

    label_7 = Label(root, text="Email-ID: ",width=20,font=("bold", 10))
    label_7.place(x=83,y=310)

    entry_7 = Entry(root)
    entry_7.place(x=255,y=310)

    label_8 = Label(root, text="Father's Name: ",width=20,font=("bold", 10))
    label_8.place(x=83,y=340)

    entry_8 = Entry(root)
    entry_8.place(x=255,y=340)

    label_9 = Label(root, text="Mother's Name: ",width=20,font=("bold", 10))
    label_9.place(x=83,y=370)

    entry_9 = Entry(root)
    entry_9.place(x=255,y=370)

    label_10 = Label(root, text="Address: ",width=20,font=("bold", 10))
    label_10.place(x=83,y=400)

    entry_10 = Entry(root)
    entry_10.place(x=255,y=400)

    chk = Checkbutton(root, text = "I hereby declare the information provided by me is legitimate.",onvalue=1,offvalue=0)
    chk.place(x=80,y=455)
    
    btn = Button(root, text="Submit", command = add_record).place(x=180,y=500)
    clear_btn = Button(root, text="Clear Fields", command = clear).place(x=259,y=500)
    close_btn = Button(root, text="Close Form", command=close_form).place(x=370,y=500)

global password_box

def mess_commands():
    
    mess_command = Tk()
    mess_command.title("Mess Info")
    mess_command.geometry('1100x600')
    
    def close_mess_info():
        mess_command.destroy()
    
    
    sql1 = """ SELECT* FROM students NATURAL JOIN mess """
    mycursor.execute(sql1)
    r = mycursor.fetchall()

    l1=Label(mess_command,text="Roll No.", font=('bold 12 underline')).grid(row=0,column=0)
    l2=Label(mess_command,text="Hostel Name", font=('bold 12 underline')).grid(row=0,column=1)
    l3=Label(mess_command,text="Hostel No.", font=('bold 12 underline')).grid(row=0,column=2)
    l4=Label(mess_command,text="Name", font=('bold 12 underline')).grid(row=0,column=3)
    l5=Label(mess_command,text="Room No.", font=('bold 12 underline')).grid(row=0,column=4)
    l6=Label(mess_command,text="Contact", font=('bold 12 underline')).grid(row=0,column=5)
    l7=Label(mess_command,text="Email-ID", font=('bold 12 underline')).grid(row=0,column=6)
    l8=Label(mess_command,text="Father's Name", font=('bold 12 underline')).grid(row=0,column=7)
    l9=Label(mess_command,text="Mother's Name", font=('bold 12 underline')).grid(row=0,column=8)
    l10=Label(mess_command,text="Address", font=('bold 12 underline')).grid(row=0,column=9)
    l11=Label(mess_command,text="Mess ID", font=('bold 12 underline')).grid(row=0,column=10)
    l12=Label(mess_command,text="Mess Status", font=('bold 12 underline')).grid(row=0,column=11)
    l13=Label(mess_command,text="Mess Fee", font=('bold 12 underline')).grid(row=0,column=12)
    l14=Label(mess_command,text="mess Fine", font=('bold 12 underline')).grid(row=0,column=13)

    for index,x in enumerate(r):
                num=0

                for y in x:
                    display_label = Label(mess_command, text=y)
                    display_label.grid(row=index+1,column=num)
                    num+=1
    
    
    sql=""" SELECT COUNT(mess_id) FROM mess WHERE mess_status="true" """ 
            
    mycursor.execute(sql)
    result2 = mycursor.fetchall()
    
    lbl1 = Label(mess_command, text="Total Students availing mess: ", font=('bold 14'))
    lbl1.place(x=450, y=300)
    
    lbl2 = Label(mess_command, text=result2)
    lbl2.place(x=650, y=300)
    
    sql2=""" SELECT SUM(mess_fee)+sum(mess_fine) as INCOME FROM mess WHERE mess_status="true" """ 
            
    mycursor.execute(sql2)
    result2 = mycursor.fetchall()
    
    lbl3 = Label(mess_command, text="Total Income of mess: ", font=('bold 14'))
    lbl3.place(x=450, y=350)
    
    lbl4 = Label(mess_command, text=result2)
    lbl4.place(x=600, y=350)
    
    close_btn = Button(mess_command, text="CLOSE", command=close_mess_info).place(x=500,y=450)


def laundry_commands():
    
    
    l_command = Tk()
    l_command.title("Laundry Info")
    l_command.geometry('1200x600')
    
    def close_laundry_info():
        l_command.destroy()
    
    sql1 = """ SELECT* FROM students NATURAL JOIN laundry """
    mycursor.execute(sql1)
    r = mycursor.fetchall()

    l1=Label(l_command,text="Roll No.", font=('bold 12 underline')).grid(row=0,column=0)
    l2=Label(l_command,text="Hostel Name", font=('bold 12 underline')).grid(row=0,column=1)
    l3=Label(l_command,text="Hostel No.", font=('bold 12 underline')).grid(row=0,column=2)
    l4=Label(l_command,text="Name", font=('bold 12 underline')).grid(row=0,column=3)
    l5=Label(l_command,text="Room No.", font=('bold 12 underline')).grid(row=0,column=4)
    l6=Label(l_command,text="Contact", font=('bold 12 underline')).grid(row=0,column=5)
    l7=Label(l_command,text="Email-ID", font=('bold 12 underline')).grid(row=0,column=6)
    l8=Label(l_command,text="Father's Name", font=('bold 12 underline')).grid(row=0,column=7)
    l9=Label(l_command,text="Mother's Name", font=('bold 12 underline')).grid(row=0,column=8)
    l10=Label(l_command,text="Address", font=('bold 12 underline')).grid(row=0,column=9)
    l11=Label(l_command,text="Laundry ID", font=('bold 12 underline')).grid(row=0,column=10)
    l12=Label(l_command,text="Laundry Status", font=('bold 12 underline')).grid(row=0,column=11)
    l13=Label(l_command,text="Laundry Fee", font=('bold 12 underline')).grid(row=0,column=12)
    l14=Label(l_command,text="Laundry Fine", font=('bold 12 underline')).grid(row=0,column=13)

    for index,x in enumerate(r):
                num=0

                for y in x:
                    display_label = Label(l_command, text=y)
                    display_label.grid(row=index+1,column=num)
                    num+=1
    
    
    sql=""" SELECT COUNT(l_id) FROM laundry WHERE l_status="true" """ 
            
    mycursor.execute(sql)
    result2 = mycursor.fetchall()
    
    lbl1 = Label(l_command, text="Total Students availing Laundry: ", font=('bold 14'))
    lbl1.place(x=450, y=300)
    
    lbl2 = Label(l_command, text=result2)
    lbl2.place(x=700, y=300)
    
    sql2=""" SELECT SUM(l_fee)+sum(l_fine) as INCOME FROM laundry WHERE l_status="true" """ 
            
    mycursor.execute(sql2)
    result2 = mycursor.fetchall()
    
    lbl3 = Label(l_command, text="Total Income of Laundry: ", font=('bold 14'))
    lbl3.place(x=450, y=350)
    
    lbl4 = Label(l_command, text=result2)
    lbl4.place(x=700, y=350)
    
    close_btn = Button(l_command, text="CLOSE", command=close_laundry_info).place(x=550,y=450)



def user():
    
    user_query = Tk()
    user_query.title("User Page")
    user_query.geometry("200x200")
    
    def close_user():
        user_query.destroy()
    
    label = Label(user_query, text="USER LOGIN",width=15,font=("bold", 16))
    label.place(x=25,y=15)
    
    btn1 = Button(user_query, text="NEW USER", command=registration).place(x=54, y=65)
    btn2 = Button(user_query, text="EXISTING USER", command=search_user).place(x=44, y=100)
    btn3 = Button(user_query, text="CLOSE", command=close_user).place(x=57,y=135)

def admin():
    
    pass_label=Label(mainroot, text="Enter Password: ")
    pass_label.place(x=140,y=195)
    pass_box = Entry(mainroot, show="*")
    pass_box.place(x=250,y=195)
    
    def admin_access():
        if(pass_box.get()=="Admin123"):
            admin_query = Tk()
            admin_query.title("Admin Page")
            admin_query.geometry("300x300")
            
            def close_admin_main():
                admin_query.destroy()

            label = Label(admin_query, text="ADMIN PAGE",width=20,font=("bold", 16))
            label.place(x=41,y=10)

            display_btn = Button(admin_query, text="DISPLAY/UPDATE RECORD", command=display).place(x=55, y=60)
            delete_btn = Button(admin_query, text="DELETE RECORD", command=delete).place(x=80, y=100)
            mess_btn = Button(admin_query, text="MESS ADMIN", command=mess_commands).place(x=95, y=140)
            laundry_btn = Button(admin_query, text="LAUNDRY ADMIN", command=laundry_commands).place(x=80, y=180)
            close_admin_btn = Button(admin_query, text="CLOSE", command=close_admin_main).place(x=120,y=220)
    
        else:
            pass_box.delete(0,END)
            display_label = Label(mainroot, text="Incorrect Password. Please Try again").place(x=200,y=265)

    
    pass_btn = Button(mainroot, text="ENTER", command=admin_access)
    pass_btn.place(x=280,y=225)
    
mainroot = Tk()
mainroot.geometry('600x400')
mainroot.title("HOSTEL DATABASE")


label = Label(mainroot, text="D.T.U HOSTEL DATABASE",font=("bold", 20))
label.place(x=200,y=50)

user_btn = Button(mainroot, text="USER LOGIN", command=user).place(x=255, y=120)
admin_btn = Button(mainroot, text="ADMIN LOGIN", command=admin).place(x=250, y=155)

mainroot.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Users/parthgupta/opt/anaconda3/lib/python3.8/tkinter/__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-1-2a777e886e19>", line 512, in add_record
#     messagebox.showinfo("SUCCESS","REGISTERED SUCCESFULLY.", parent=root)
# NameError: name 'messagebox' is not defined
